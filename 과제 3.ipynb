# %% [markdown]
# ## 1. 파이썬 기본
# ### 세미콜론 사용 유무

# %%
a=1;b=2;c=3
print(a,b,c)

# %% [markdown]
# ### 들여쓰기

# %% [markdown]
# ## 2. 출력(print())

# %% [markdown]
# ### 문자출력

# %% [markdown]
# 셀의 맨 마지막을 항상 출력합니다

# %% [markdown]
# print 구문을 붙혀 주면 중간에서도 출력합니다.

# %% [markdown]
# ### 숫자 출력
# 1. **'  '**  없이 출력

# %% [markdown]
# 2. **' '** 있는 경우 출력
# - 정수, 실수

# %% [markdown]
# ### 변수 값 출력

# %% [markdown]
# ##  format() 사용

# %% [markdown]
# ##  공백, 줄바꿈 (\n)

# %% [markdown]
# ##  sep=' ' 사용

# %% [markdown]
# ##  end=' ' 사용

# %% [markdown]
# ## 3.input()

# %% [markdown]
# ### input()만 사용

# %% [markdown]
# ### input('설명') 사용

# %% [markdown]
# ### input값 정수와 실수

# %% [markdown]
# ### input값 정수와 실수 변수에 대입

# %% [markdown]
# ### input값 여러개 한번에 저장:split()

# %% [markdown]
# ### input값 한번에 저장 된 값 정수와 실수로 변수에 저장

# %% [markdown]
# ### input값 한번에 정수와 실수로 변수에 저장:map()
